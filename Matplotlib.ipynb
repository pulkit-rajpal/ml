# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import numpy as np
style.use('dark_background')

# %%
housing = pd.read_csv('C:/Users/student711/Desktop/pulkit/DataSets-master/DataSets-master/Housing_Data.csv')

'''
X = [1,23,2,34,8,23]
Y = [2,21,5,31,7,23]
Z = [2,2231,235,3231,7,2233]
'''
housing
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
plt.title("Matplotlib Plotting")
plt.xlabel('X-axis')
plt.ylabel('YY-axis')
plt.plot(X, Y,'or', c= 'm', marker ='*')
plt.plot(X, Z, '*b',c= 'g', marker ='+')
plt.legend(["India", "China"])
plt.show()

# %%
house_price = housing["price"]

# %%
shouse_lotsize = housing["lotsize"]

# %%
#style.use('ggplot')
plt.title("Housing Data")
plt.xlabel("lotsize")
plt.ylabel("Prize")
plt.legend(["Housing"])
plt.plot(housing.lotsize,housing.price, '*r')
plt.show()

# %%
mean = pd.DataFrame.mean(shouse_lotsize)

# %%
housing.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
# MOde is the frequency of the data 

xx = pd.unique(housing.lotsize)

# %%
xx.mean()
# Out:
# 5397.827464788732

# %%
house_lotsize.mean()
# Out:
# 5150.2655677655675

# %%
house_lotsize.median()
# Out:
# 4600.0

# %%
house_lotsize.std()
# Out:
# 2168.1587252285567

# %%
xx.std()
# Out:
# 2484.6947587531276

# %%
type(house_lotsize)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ####  Mean is the sum of the data / total no of the data
# ####  mode is the frequency of the data
# ####  median is the middle term
# ####  std. dev is how we are far from the mean

# %%
p = np.asarray(house_lotsize)
p
# Out:
# array([ 5850,  4000,  3060,  6650,  6360,  4160,  3880,  4160,  4800,
#         5500,  7200,  3000,  1700,  2880,  3600,  3185,  3300,  5200,
#         3450,  3986,  4785,  4510,  4000,  3934,  4960,  3000,  3800,
#         4960,  3000,  4500,  3500,  3500,  4000,  4500,  6360,  4500,
#         4032,  5170,  5400,  3150,  3745,  4520,  4640,  8580,  2000,
#         2160,  3040,  3090,  4960,  3350,  5300,  4100,  9166,  4040,
#         3630,  3620,  2400,  7260,  4400,  2400,  4120,  4750,  4280,
#         4820,  5500,  5500,  5040,  6000,  2500,  4095,  4095,  3150,
#         1836,  2475,  3210,  3180,  1650,  3180,  3180,  6360,  4240,
#         3240,  3650,  3240,  3780,  6480,  5850,  3150,  3000,  3090,
#         6060,  5900,  7420,  8500,  8050,  6800,  8250,  8250,  3500,
#         2835,  4500,  3300,  4320,  3500,  4992,  4600,  3720,  3680,
#         3000,  3750,  5076,  4500,  5000,  4260,  6540,  3700,  3760,
# ...

# %%
p = np.array([1,2,3,23,23,23,2])

# %%
#x_2d = p.reshape(-1,1)

# %%
p
# Out:
# array([ 1,  2,  3, 23, 23, 23,  2])

# %%
p = np.array([1,2,3,23,23,23,2,12,12])

# %%
my4X3 = np.resize(p,(4,5))

# %%
print(my4X3)
# Out:
# [[ 1  2  3 23 23]
#  [23  2 12 12  1]
#  [ 2  3 23 23 23]
#  [ 2 12 12  1  2]]

# %%
housing.head(3)
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no

# %%
p = house_price.shape

# %%
p = np.asarray(p)

# %%
xx_data = housing[["price", "lotsize"]]

# %%
type(xx_data)
# Out:
# pandas.core.frame.DataFrame

# %%
xx_data = np.reshape(xx_data, (-1,2))

# %%
xx_data
# Out:
# array([[  42000.,    5850.],
#        [  38500.,    4000.],
#        [  49500.,    3060.],
#        ...,
#        [ 103000.,    6000.],
#        [ 105000.,    6000.],
#        [ 105000.,    6000.]])

# %%
x_data[:-12]
# Out:
# array([[  42000.],
#        [  38500.],
#        [  49500.],
#        [  60500.],
#        [  61000.],
#        [  66000.],
#        [  66000.],
#        [  69000.],
#        [  83800.],
#        [  88500.],
#        [  90000.],
#        [  30500.],
#        [  27000.],
#        [  36000.],
#        [  37000.],
#        [  37900.],
#        [  40500.],
#        [  40750.],
#        [  45000.],
#        [  45000.],
#        [  48500.],
#        [  65900.],
#        [  37900.],
#        [  38000.],
#        [  42000.],
#        [  42300.],
#        [  43500.],
#        [  44000.],
#        [  44500.],
#        [  44900.],
#        [  45000.],
#        [  48000.],
#        [  49000.],
#        [  51500.],
#        [  61000.],
#        [  61000.],
#        [  61700.],
#        [  67000.],
#        [  82000.],
#        [  54500.],
#        [  66500.],
#        [  70000.],
#        [  82000.],
#        [  92000.],
#        [  38000.],
#        [  44000.],
#        [  41000.],
# ...

# %%
x_input = housing.price
y_output = housing.lotsize

# %%
from sklearn.model_selection import train_test_split

# %%
# random state preserve the state for the randomness of the split
x1, x2, y1, y2 = train_test_split(x_input, y_output, test_size = .20, random_state =8)

# %%
x1
# Out:
# 273     64900.0
# 40      66500.0
# 397     80750.0
# 339     62500.0
# 411     95000.0
# 535     82000.0
# 414     52000.0
# 142     51000.0
# 29      44900.0
# 501     68500.0
# 16      40500.0
# 85      57000.0
# 523    110000.0
# 312     70000.0
# 364     84900.0
# 244     32500.0
# 258     33500.0
# 349     64000.0
# 102    125000.0
# 439     69000.0
# 162     25000.0
# 520    103000.0
# 128    123500.0
# 285     65000.0
# 224     87250.0
# 110     43000.0
# 328    115442.0
# 516     95000.0
# 292     45000.0
# 304     60000.0
#          ...
# 431     65000.0
# 264     50000.0
# 209     92500.0
# 316     80000.0
# 513     66000.0
# 313     75000.0
# 319     83000.0
# 7       69000.0
# 393    106000.0
# 141     40000.0
# 86      60000.0
# 478     88000.0
# 503     70500.0
# 215     41000.0
# 398     82900.0
# 490     50000.0
# 252     53900.0
# 468     55000.0
# 357     95000.0
# 254     61000.0
# 276     70000.0
# 178     74500.0
# 281     74500.0
# 390     86900.0
# ...
